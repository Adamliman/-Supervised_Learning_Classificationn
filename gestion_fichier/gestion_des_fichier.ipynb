# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\Liman\\Downloads\\Loan_prediction_dataset.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
moyenne = np.mean(data)
moyenne
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 moyenne = np.mean(data)
#       2 moyenne
#
# File c:\Users\Liman\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\fromnumeric.py:3902, in mean(a, axis, dtype, out, keepdims, where)
#    3900         pass
#    3901     else:
# -> 3902         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3904 return _methods._mean(a, axis=axis, dtype=dtype,
#    3905                       out=out, **kwargs)
#
# File c:\Users\Liman\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
# ...
